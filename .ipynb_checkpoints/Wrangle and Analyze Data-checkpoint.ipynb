# %% [markdown]
# # Project 06: Wrangle and Analyze Data
# Note: Meisam Heidari and I have done the project together as a team. We are both the students of the data analysis nano degree program. We are trying to work together to understand and fill the each other's gaps for better learning and project delivering.
#
# ## Project Motivation keys
#
# ### Key Points
# Key points to keep in mind when data wrangling for this project:
#
# - **You only want original ratings (no retweets) that have images**. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# - Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least `8 quality` issues and at least `2 tidiness` issues in this dataset.
# - Cleaning includes merging individual pieces of data according to the rules of tidy data.
# - The fact that the rating numerators are greater than the denominators does not need to be cleaned. This unique rating system is a big part of the popularity of WeRateDogs.
# - You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
import requests
import os
import ast
from IPython.display import Image
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline

# %% [markdown]
# ## Gather

# %%
df_enhanced = pd.read_csv('Udacity_twitter-archive-enhanced.csv')
df_enhanced
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
(df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo']).unique()
# Out:
# array(['NoneNoneNoneNone', 'doggoNoneNoneNone', 'NoneNoneNonepuppo',
#        'NoneNonepupperNone', 'NoneflooferNoneNone', 'doggoNoneNonepuppo',
#        'doggoflooferNoneNone', 'doggoNonepupperNone'], dtype=object)

# %%
sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='NoneNoneNoneNone')
# Out:
# 1976

# %%
sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='doggoNoneNoneNone')
# Out:
# 83

# %%
sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='NoneNoneNonepuppo')
# Out:
# 29

# %%
sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='NoneNonepupperNone')
# Out:
# 245

# %%
sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='NoneflooferNoneNone')
# Out:
# 9

# %%
doggoNoneNonepuppo = sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='doggoNoneNonepuppo')
doggoflooferNoneNone = sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='doggoflooferNoneNone')
doggoNonepupperNone = sum((df_enhanced['doggo']+df_enhanced['floofer']+df_enhanced['pupper']+df_enhanced['puppo'])=='doggoNonepupperNone')
doggoNoneNonepuppo+doggoflooferNoneNone+doggoNonepupperNone
# Out:
# 14

# %%
consumer_key = '4qeT9WD9TeWSCyuLnCjzlrkFa'
consumer_secret = 'SJ0V8ePgc6rtMwSKKY8R4DbgbVT6QeZkOUn3W0jxJShG65Lym8'
access_token = '1143347401303842816-3i4bOuEWlpCsnViHZ29XhMluJzE2Xd'
access_secret = 'wdOWftzpqlxw4w0zF1611eKykL1laRJKwnE3vDcNcr9G4'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweet_ids = df_enhanced.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %%
df_all_tweets = []
count = 0
with open('tweet_json.txt', 'r') as f:
    for lines in f.readlines():
        df_all_tweets.append(json.loads(lines))
df_all_tweets = pd.DataFrame(df_all_tweets)
df_all_tweets
# Out:
#      contributors coordinates                      created_at  \
# 0            None        None  Tue Aug 01 16:23:56 +0000 2017
# 1            None        None  Tue Aug 01 00:17:27 +0000 2017
# 2            None        None  Mon Jul 31 00:18:03 +0000 2017
# 3            None        None  Sun Jul 30 15:58:51 +0000 2017
# 4            None        None  Sat Jul 29 16:00:24 +0000 2017
# 5            None        None  Sat Jul 29 00:08:17 +0000 2017
# 6            None        None  Fri Jul 28 16:27:12 +0000 2017
# 7            None        None  Fri Jul 28 00:22:40 +0000 2017
# 8            None        None  Thu Jul 27 16:25:51 +0000 2017
# 9            None        None  Wed Jul 26 15:59:51 +0000 2017
# 10           None        None  Wed Jul 26 00:31:25 +0000 2017
# 11           None        None  Tue Jul 25 16:11:53 +0000 2017
# 12           None        None  Tue Jul 25 01:55:32 +0000 2017
# 13           None        None  Tue Jul 25 00:10:02 +0000 2017
# ...

# %%
# Number of tweets that are probably deleted and are not available for download
len(df_all_tweets)-len(df_enhanced)
# Out:
# -22

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'

# %%
response = requests.get(url)
with open('image-predictions.tsv',mode='wb') as file:
    file.write(response.content)

# %%
df_images = pd.read_csv('image-predictions.tsv',sep='\t')
df_images
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
#Number of fields with no images:
len(df_all_tweets)-len(df_images)
# Out:
# 259

# %% [markdown]
# ## Assess

# %%
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# `[doggo, floofer, pupper,puppo]` have `None` large number of values but they are not showing as null values in the dataframe `info()`

# %%
df_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_all_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2334 entries, 0 to 2333
# Data columns (total 32 columns):
# contributors                     0 non-null object
# coordinates                      0 non-null object
# created_at                       2334 non-null object
# display_text_range               2334 non-null object
# entities                         2334 non-null object
# extended_entities                2062 non-null object
# favorite_count                   2334 non-null int64
# favorited                        2334 non-null bool
# full_text                        2334 non-null object
# geo                              0 non-null object
# id                               2334 non-null int64
# id_str                           2334 non-null object
# in_reply_to_screen_name          77 non-null object
# in_reply_to_status_id            77 non-null float64
# in_reply_to_status_id_str        77 non-null object
# in_reply_to_user_id              77 non-null float64
# ...

# %%
df_all_tweets[['in_reply_to_screen_name','in_reply_to_status_id','in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str']]
# Out:
#      in_reply_to_screen_name  in_reply_to_status_id in_reply_to_status_id_str  \
# 0                       None                    NaN                      None
# 1                       None                    NaN                      None
# 2                       None                    NaN                      None
# 3                       None                    NaN                      None
# 4                       None                    NaN                      None
# 5                       None                    NaN                      None
# 6                       None                    NaN                      None
# 7                       None                    NaN                      None
# 8                       None                    NaN                      None
# 9                       None                    NaN                      None
# 10                      None                    NaN                      None
# ...

# %%
mask = df_all_tweets.quoted_status_permalink.notnull()
#column_name = 'retweeted_status'
df_all_tweets.loc[mask,('id_str','quoted_status','quoted_status_id','quoted_status_id_str','quoted_status_permalink')]
# Out:
#                   id_str                                      quoted_status  \
# 31    886054160059072513                                                NaN
# 41    884247878851493888  {'created_at': 'Sun Jul 09 08:26:49 +0000 2017...
# 71    878604707211726852  {'created_at': 'Sat Jun 24 13:05:06 +0000 2017...
# 82    876537666061221889  {'created_at': 'Sat Jun 17 19:41:50 +0000 2017...
# 87    875097192612077568  {'created_at': 'Mon Jun 12 23:49:34 +0000 2017...
# 106   871102520638267392  {'created_at': 'Sat Jun 03 18:46:59 +0000 2017...
# 127   866720684873056260  {'created_at': 'Mon May 22 01:00:31 +0000 2017...
# 184   855818117272018944  {'created_at': 'Sat Apr 22 05:36:05 +0000 2017...
# 232   846505985330044928  {'created_at': 'Mon Mar 27 22:11:17 +0000 2017...
# 234   846139713627017216  {'created_at': 'Sun Mar 26 19:56:27 +0000 2017...
# 257   841320156043304961  {'created_at': 'Mon Mar 13 15:34:02 +0000 2017...
# ...

# %%
list(df_enhanced)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
list(df_all_tweets)
# Out:
# ['contributors',
#  'coordinates',
#  'created_at',
#  'display_text_range',
#  'entities',
#  'extended_entities',
#  'favorite_count',
#  'favorited',
#  'full_text',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'place',
#  'possibly_sensitive',
#  'possibly_sensitive_appealable',
#  'quoted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'quoted_status_permalink',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'source',
#  'truncated',
#  'user']

# %%
# Display_text_range is a list, not hashable, it is going to create issues with some of 
# vectorized pandas/Numby functions. We need to change it to a different data type. But first,
# lets see if any of the firts items in each list is not zero:

df_all_tweets['display_text_range'][df_all_tweets['display_text_range'].str[0] != 0]
# Out:
# 29      [27, 105]
# 54       [13, 91]
# 63       [16, 31]
# 109      [30, 60]
# 142     [17, 134]
# 172      [10, 28]
# 178     [28, 165]
# 180      [14, 86]
# 181      [5, 133]
# 209     [12, 136]
# 225      [18, 79]
# 262      [12, 56]
# 278      [12, 18]
# 279      [23, 63]
# 299      [22, 98]
# 328      [13, 40]
# 332       [5, 22]
# 393      [15, 20]
# 411       [7, 56]
# 558     [13, 105]
# 593      [16, 55]
# 837      [14, 81]
# 1059     [13, 18]
# Name: display_text_range, dtype: object

# %%
df_all_tweets[df_all_tweets['display_text_range'].str[0] != 0]
# Out:
#      contributors coordinates                      created_at  \
# 29           None        None  Sat Jul 15 16:51:35 +0000 2017
# 54           None        None  Sun Jul 02 21:58:53 +0000 2017
# 63           None        None  Tue Jun 27 12:14:36 +0000 2017
# 109          None        None  Fri Jun 02 19:38:25 +0000 2017
# 142          None        None  Sat May 13 16:15:35 +0000 2017
# 172          None        None  Wed Apr 26 12:48:51 +0000 2017
# 178          None        None  Sun Apr 23 23:26:03 +0000 2017
# 180          None        None  Sat Apr 22 19:15:32 +0000 2017
# 181          None        None  Sat Apr 22 19:05:32 +0000 2017
# 209          None        None  Fri Apr 07 13:04:55 +0000 2017
# 225          None        None  Fri Mar 31 01:11:22 +0000 2017
# 262          None        None  Sat Mar 11 22:59:09 +0000 2017
# 278          None        None  Sat Mar 04 22:12:52 +0000 2017
# 279          None        None  Sat Mar 04 17:56:49 +0000 2017
# ...

# %%
df_enhanced.nunique()
# Out:
# tweet_id                      2356
# in_reply_to_status_id           77
# in_reply_to_user_id             31
# timestamp                     2356
# source                           4
# text                          2356
# retweeted_status_id            181
# retweeted_status_user_id        25
# retweeted_status_timestamp     181
# expanded_urls                 2218
# rating_numerator                40
# rating_denominator              18
# name                           957
# doggo                            2
# floofer                          2
# pupper                           2
# puppo                            2
# dtype: int64

# %%
# Seems the only value stored in df_all_tweets.truncated is False. Lets check that:
df_all_tweets['truncated'].unique()
# Out:
# array([False])

# %%
df_enhanced.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
# Seems there are rating_denominators which are not 10. It doesnt follow the system of rating here. 
# Let's investigate how many of them are around and how does the dataframe looks in those lines:
df_enhanced[df_enhanced['rating_denominator']!=10].count()
# Out:
# tweet_id                      23
# in_reply_to_status_id          5
# in_reply_to_user_id            5
# timestamp                     23
# source                        23
# text                          23
# retweeted_status_id            1
# retweeted_status_user_id       1
# retweeted_status_timestamp     1
# expanded_urls                 19
# rating_numerator              23
# rating_denominator            23
# name                          23
# doggo                         23
# floofer                       23
# pupper                        23
# puppo                         23
# dtype: int64

# %%
df_enhanced[df_enhanced['rating_denominator']!=10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %%
# Lets find the duplicated column names between all dataframes
all_col = pd.Series(list(df_all_tweets)+list(df_enhanced)+list(df_images))
list(all_col[all_col.duplicated()])
# Out:
# ['in_reply_to_status_id', 'in_reply_to_user_id', 'source', 'tweet_id']

# %% [markdown]
# ### Quality

# %% [markdown]
# **`df_all_tweets` table**
#
#
# - `id` and `id_str` coloumns don't match. Tweeter developer guide for JSON objects suggest `id_str` is the correct user ID while `id` is not. Keep `id_str` and drop`id`.- Done
# - `display_text_range` is stored as a list and is not hashable. It makes it very difficult to use some of the pandas methods on the dataframe. Chnage it to 2 columns with start and finish as integers for futur operation(maybe in ML).-Done
# - `display_text-range` is a list. there are 23 lines with first item in the list being non-zero. it means that the texts is truncated. once mergerd, instead of relying on `text` column from `df_enhanced`, we should use `full_text` from `df_all_tweets`. So drop the `text` column from `df_enhanced`-Done
#
# - Tweeter api couldn't download 22 of the tweets probably because those tweets are deleted. Find those and remove from df_enhanced-Done
# - non-null values in the **['in_reply_to_screen_name','in_reply_to_status_id', 'in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str']** columns suggest the tweet was written in reply to another user and is not original. We need to remove them.-Done
#     - Once these rows were removed, above columns remain filled with null values and become redundant. remove them. -Done.
#
# - **`source` column contains an html like tag format. 3 different sources of data is clear. they need to be parsed.**
# - `created_at` is an string object, it must be in timestamp format.-Done
# - there are multiple rows in the Dataframe where a single doge has more than one stage such as `doggo` and `puppo` at the same time. These needs to be removed.-Done
#
#
#
#
#
# **`df_enhanced` table**
#
# - `id_str` is an object made of strings. Considering `id-str` is a categorical data, all of them must be string. -Done
# - There are 23 data lines with `rating_denominator` different than 10. It doesn't follow their rating system. These data must be further looked at after merging and possibly corrected/dropped.-done
# - `timestamp` is an string object, it must be in timestamp format.-Done
# - all 'None' and 'NaN' values are not Pandas's null values.-Done
#
#
#
# **`df_images` table**
#
# - `tweet_id` is an object made of strings. Considering `tweet_id` is a categorical data, all of them must be string.-Done

# %% [markdown]
# ### Tidiness
#
# - ['in_reply_to_status_id', 'in_reply_to_user_id', 'source'] columns are duplicated between `df_all_tweets` and `df_enhanced`. drop them from `df_enhanced` and keep `df_all_tweets`.-Done
# - `df_enhanced` and `df_all_tweets` should be merged into one table based on their `tweet_id` aka `is_str`. `df_all_tweets` is downloaded recently so when there is an overlap between columns/data, the data from `df_all_tweets` should be used.-Done
# - rename `id_str` to ` tweet_id` to be similar to the other tables for future merge/concat-Done
#
#
# **`df_all_tweets` table**
#
# - following columns have between 0 to 165 datapoints. No reliable interpretation is possible. Delete them:
# ['contributors','coordinates','geo','place']-Done
#
# **`df_enhanced` table**
# - all of these 4 categorical columns, ['doggo','floofer','pupper','puppo'], can be combined to one categorical column.-Done
# - Drop unnecessary columns of ['doggo','floofer','pupper','puppo'] after combining them-Done

# %% [markdown]
# ## Clean

# %%
df_all_tweets_clean = df_all_tweets.copy()
df_enhanced_clean = df_enhanced.copy()
df_images_clean = df_images.copy()

# %% [markdown]
# #### Define
# - All of these 4 categorical columns: ['doggo','floofer','pupper','puppo'] in 'df_enhanced_clean_None' dataframe can be combined to one categorical column.
# - there are multiple rows in the Dataframe where a single doge has more than one stage such as `doggo` and `puppo` at the same time. These needs to be removed.
#
# #### Code

# %%
df_enhanced_clean['dog_stage']=(df_enhanced_clean['doggo']+df_enhanced_clean['floofer']+df_enhanced_clean['pupper']+
                                df_enhanced_clean['puppo'])
df_enhanced_clean['dog_stage'].unique()
# Out:
# array(['NoneNoneNoneNone', 'doggoNoneNoneNone', 'NoneNoneNonepuppo',
#        'NoneNonepupperNone', 'NoneflooferNoneNone', 'doggoNoneNonepuppo',
#        'doggoflooferNoneNone', 'doggoNonepupperNone'], dtype=object)

# %%
df_enhanced_clean.replace('NoneNoneNoneNone',np.nan ,inplace=True)
df_enhanced_clean.replace('doggoNoneNoneNone','doggo' ,inplace=True)
df_enhanced_clean.replace('NoneNoneNonepuppo','puppo' ,inplace=True)
df_enhanced_clean.replace('NoneNonepupperNone','pupper' ,inplace=True)
df_enhanced_clean.replace('NoneflooferNoneNone','floofer' ,inplace=True)
df_enhanced_clean.replace('doggoNoneNonepuppo',np.nan ,inplace=True)
df_enhanced_clean.replace('doggoflooferNoneNone',np.nan ,inplace=True)
df_enhanced_clean.replace('doggoNonepupperNone',np.nan ,inplace=True)

# %% [markdown]
# #### Test

# %%
df_enhanced_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df_enhanced_clean
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# #### Define
# - all 'None' and 'NaN' string values are not Pandas's real null values.
#
# #### Code

# %%
df_enhanced_clean.replace('None',np.nan ,inplace=True)
df_enhanced_clean.replace('NaN',np.nan ,inplace=True)

# %%
#df_enhanced_clean_None = df_enhanced_clean 
#df_enhanced_clean_None.replace('None',np.nan ,inplace=True)

# %%
# Check whether there is any 'NaN' value in the dataframe
#df_NaN_check = df_enhanced_clean_None == 'NaN'
#df_NaN_check.sample(2)

# %% [markdown]
# #### Test

# %%
# Checking that all 'None' Values are removed:
df_enhanced_clean[df_enhanced_clean.eq('None').any(1)]
# Out:
# /Users/Meisam/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, dog_stage]
# Index: []

# %%
# Since the last method gave us a warning, lets try a nother method:
df_enhanced_clean[(df_enhanced_clean.values.ravel() == 'None').
                  reshape(df_enhanced_clean.shape).any(1)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, dog_stage]
# Index: []

# %%
# Since the last method gave us a warning, lets try a nother method:
df_enhanced_clean[(df_enhanced_clean.values.ravel() == 'NaN').
                  reshape(df_enhanced_clean.shape).any(1)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, dog_stage]
# Index: []

# %%
# Confirm there is only False in df_NaN_check dataframe, so there is no 'NaN' value in df_enhanced_clean_None dataframe.
#df_NaN_check.nunique()

# %%
# 'None' string has been converted to real null value for columns: 'Name', 'doggo', floofer', 'pupper' and 'puppo'.
df_enhanced_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          1611 non-null object
# doggo                         97 non-null object
# floofer                       10 non-null object
# pupper                        257 non-null object
# ...

# %% [markdown]
# #### Define
# - Drop unnecessary columns of ['doggo','floofer','pupper','puppo'] after combining them from df_enhanced

# %% [markdown]
# #### Code

# %%
df_enhanced_clean= df_enhanced_clean.drop(['doggo','floofer','pupper','puppo'], axis=1)

# %% [markdown]
# #### Test

# %%
df_enhanced_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          1611 non-null object
# dog_stage                     366 non-null object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 257.8+ KB

# %% [markdown]
# #### Define
# - ['in_reply_to_status_id', 'in_reply_to_user_id', 'source'] columns are duplicated between `df_all_tweets` and `df_enhanced`. drop them from `df_enhanced` and keep `df_all_tweets`.
#
# #### Code

# %%
df_enhanced_clean = df_enhanced_clean.drop(['in_reply_to_status_id', 'in_reply_to_user_id', 'source'], axis=1)

# %% [markdown]
# #### Test

# %%
df_enhanced_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 11 columns):
# tweet_id                      2356 non-null int64
# timestamp                     2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          1611 non-null object
# dog_stage                     366 non-null object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 202.5+ KB

# %% [markdown]
# #### Define
# - following columns have no datapoints.
# ['contributors','coordinates','geo','place']
#
# Therefore, these columns should be removed.
# #### Code

# %%
# Drop the 4 columns: ['contributors','coordinates','geo','place']
df_all_tweets_clean= df_all_tweets.drop(['contributors','coordinates','geo','place'], axis=1)

# %% [markdown]
# #### Test

# %%
# Confirm whether the columns have been dropped.
df_all_tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2334 entries, 0 to 2333
# Data columns (total 28 columns):
# created_at                       2334 non-null object
# display_text_range               2334 non-null object
# entities                         2334 non-null object
# extended_entities                2062 non-null object
# favorite_count                   2334 non-null int64
# favorited                        2334 non-null bool
# full_text                        2334 non-null object
# id                               2334 non-null int64
# id_str                           2334 non-null object
# in_reply_to_screen_name          77 non-null object
# in_reply_to_status_id            77 non-null float64
# in_reply_to_status_id_str        77 non-null object
# in_reply_to_user_id              77 non-null float64
# in_reply_to_user_id_str          77 non-null object
# is_quote_status                  2334 non-null bool
# lang                             2334 non-null object
# ...

# %% [markdown]
# #### Define
# **`df_enhanced` table**
#
# - `tweet_id` is an object made of strings. Considering `tweet_id` is a categorical data, all of them must be string.
#
# **`df_images` table**
#
# - `tweet_id` is an object made of strings. Considering `tweet_id` is a categorical data, all of them must be string.

# %% [markdown]
# #### Code

# %%
df_enhanced_clean.tweet_id = df_enhanced_clean.tweet_id.astype('str')

# %%
df_images_clean.tweet_id = df_images_clean.tweet_id.astype('str')

# %% [markdown]
# #### Test

# %%
df_enhanced_clean.dtypes
# Out:
# tweet_id                       object
# timestamp                      object
# text                           object
# retweeted_status_id           float64
# retweeted_status_user_id      float64
# retweeted_status_timestamp     object
# expanded_urls                  object
# rating_numerator                int64
# rating_denominator              int64
# name                           object
# dog_stage                      object
# dtype: object

# %%
df_images_clean.dtypes
# Out:
# tweet_id     object
# jpg_url      object
# img_num       int64
# p1           object
# p1_conf     float64
# p1_dog         bool
# p2           object
# p2_conf     float64
# p2_dog         bool
# p3           object
# p3_conf     float64
# p3_dog         bool
# dtype: object

# %% [markdown]
# #### Define
# **`df_all_tweets` table**
#
#
# - `created_at` is an string object, it must be in timestamp format.
#
# **`df_enhanced` table**
#
# - `timestamp` is an string object, it must be in timestamp format.

# %% [markdown]
# #### Code

# %%
df_all_tweets_clean.created_at= pd.to_datetime(df_all_tweets_clean.created_at)

# %%
df_enhanced_clean.timestamp= pd.to_datetime(df_enhanced_clean.timestamp)

# %% [markdown]
# #### Test

# %%
df_all_tweets_clean.created_at.dtypes
# Out:
# datetime64[ns, UTC]

# %%
df_enhanced_clean.timestamp.dtypes
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# #### Define
# **`df_all_tweets` table**
# - `id` and `id_str` coloumns don't match. Tweeter developer guide for JSON objects suggest `id_str` is the correct user ID while `id` is not. Keep `id_str` and drop`id`.
# - rename `id_str` to ` tweet_id` to be similar to the other tables for future merge/concat

# %% [markdown]
# #### Code

# %%
df_all_tweets_clean.rename(columns={'id_str': 'tweet_id'}, inplace=True)

# %%
df_all_tweets_clean.drop(['id'], axis =1, inplace = True)

# %% [markdown]
# #### Test

# %%
df_all_tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2334 entries, 0 to 2333
# Data columns (total 27 columns):
# created_at                       2334 non-null datetime64[ns, UTC]
# display_text_range               2334 non-null object
# entities                         2334 non-null object
# extended_entities                2062 non-null object
# favorite_count                   2334 non-null int64
# favorited                        2334 non-null bool
# full_text                        2334 non-null object
# tweet_id                         2334 non-null object
# in_reply_to_screen_name          77 non-null object
# in_reply_to_status_id            77 non-null float64
# in_reply_to_status_id_str        77 non-null object
# in_reply_to_user_id              77 non-null float64
# in_reply_to_user_id_str          77 non-null object
# is_quote_status                  2334 non-null bool
# lang                             2334 non-null object
# ...

# %% [markdown]
# #### Define
# **`df_all_tweets` table**
# - `display_text_range` is stored as a list and is not hashable. It makes it very difficult to use some of the pandas methods on the dataframe. Chnage it to 2 columns with start and finish as integers for futur operation(maybe in ML).
#
# **`df_enhanced` table**
# - `display_text-range` is a list. there are 23 lines with first item in the list being non-zero. it means that the texts is truncated. once mergerd, instead of relying on `text` column from `df_enhanced`, we should use `full_text` from `df_all_tweets`. So drop the `text` column from `df_enhanced`

# %% [markdown]
# #### Code

# %%
df_enhanced_clean.drop(['text'], axis =1, inplace = True)

# %%
temp = df_all_tweets_clean.display_text_range.apply(pd.Series)
temp.rename(columns={0:'display_text_start',1:'display_text_finish',}
            ,inplace=True)
temp = pd.merge(temp, df_all_tweets_clean, right_index = True, left_index = True
                                )
temp.drop(['display_text_range'], axis =1, inplace = True)


# rearranging coulns to have tweet_id and created_at first
columns_sorted = ['tweet_id',
 'created_at',
 'display_text_start',
 'display_text_finish',
 'entities',
 'extended_entities',
 'favorite_count',
 'favorited',
 'full_text',
 'in_reply_to_screen_name',
 'in_reply_to_status_id',
 'in_reply_to_status_id_str',
 'in_reply_to_user_id',
 'in_reply_to_user_id_str',
 'is_quote_status',
 'lang',
 'possibly_sensitive',
 'possibly_sensitive_appealable',
 'quoted_status',
 'quoted_status_id',
 'quoted_status_id_str',
 'quoted_status_permalink',
 'retweet_count',
 'retweeted',
 'retweeted_status',
 'source',
 'truncated',
 'user']


temp = temp[columns_sorted]
df_all_tweets_clean = temp.copy()

# %% [markdown]
# #### Test

# %%
df_all_tweets_clean
# Out:
#                 tweet_id                created_at  display_text_start  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00                   0
# 1     892177421306343426 2017-08-01 00:17:27+00:00                   0
# 2     891815181378084864 2017-07-31 00:18:03+00:00                   0
# 3     891689557279858688 2017-07-30 15:58:51+00:00                   0
# 4     891327558926688256 2017-07-29 16:00:24+00:00                   0
# 5     891087950875897856 2017-07-29 00:08:17+00:00                   0
# 6     890971913173991426 2017-07-28 16:27:12+00:00                   0
# 7     890729181411237888 2017-07-28 00:22:40+00:00                   0
# 8     890609185150312448 2017-07-27 16:25:51+00:00                   0
# 9     890240255349198849 2017-07-26 15:59:51+00:00                   0
# 10    890006608113172480 2017-07-26 00:31:25+00:00                   0
# 11    889880896479866881 2017-07-25 16:11:53+00:00                   0
# ...

# %%
df_enhanced_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 10 columns):
# tweet_id                      2356 non-null object
# timestamp                     2356 non-null datetime64[ns, UTC]
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          1611 non-null object
# dog_stage                     366 non-null object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(2), object(5)
# memory usage: 184.1+ KB

# %% [markdown]
# #### Define
# **`df_all_tweets` table**
#
# - non-null values in the **['in_reply_to_screen_name','in_reply_to_status_id', 'in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str']** columns suggest the tweet was written in reply to another user and is not original. We need to remove them.
# - Once these rows were removed, above columns remain filled with null values and become redundant. remove them.

# %% [markdown]
# #### Code

# %%
temp = df_all_tweets_clean[df_all_tweets_clean.in_reply_to_screen_name.isnull()].copy()
temp.drop(['in_reply_to_screen_name','in_reply_to_status_id',
                          'in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str'],
                         axis =1, inplace = True)
df_all_tweets_clean = temp.copy()

# %% [markdown]
# #### Test

# %%
df_all_tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2257 entries, 0 to 2333
# Data columns (total 23 columns):
# tweet_id                         2257 non-null object
# created_at                       2257 non-null datetime64[ns, UTC]
# display_text_start               2257 non-null int64
# display_text_finish              2257 non-null int64
# entities                         2257 non-null object
# extended_entities                2039 non-null object
# favorite_count                   2257 non-null int64
# favorited                        2257 non-null bool
# full_text                        2257 non-null object
# is_quote_status                  2257 non-null bool
# lang                             2257 non-null object
# possibly_sensitive               2177 non-null object
# possibly_sensitive_appealable    2177 non-null object
# quoted_status                    24 non-null object
# quoted_status_id                 26 non-null float64
# ...

# %% [markdown]
# #### Define
# **`df_enhanced` table:**
# - There are 23 data lines with `rating_denominator` different than 10. It doesn't follow their rating system. These data must be further looked at after merging and possibly corrected/dropped.

# %% [markdown]
# #### Code

# %%
df_enhanced_clean = df_enhanced_clean[df_enhanced_clean.rating_denominator==10]

# %% [markdown]
# #### Test

# %%
df_enhanced_clean[df_enhanced_clean.rating_denominator!=10].count()
# Out:
# tweet_id                      0
# timestamp                     0
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 0
# rating_numerator              0
# rating_denominator            0
# name                          0
# dog_stage                     0
# dtype: int64

# %% [markdown]
# #### Define
# - `df_enhanced` and `df_all_tweets` should be merged into one table based on their `tweet_id` aka `id_str`. `df_all_tweets` is downloaded recently so if there is an overlap between columns/data, the data from `df_all_tweets` should be used.
#
# - Tweeter api couldn't download 22 of the tweets probably because those tweets are deleted. Find those and remove from df_enhanced. (This will be don as a part of merge.)

# %% [markdown]
# #### Code

# %%
tweets_merged = pd.merge(df_all_tweets_clean, df_enhanced_clean, on='tweet_id')

# %% [markdown]
# #### Test

# %%
tweets_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2240 entries, 0 to 2239
# Data columns (total 32 columns):
# tweet_id                         2240 non-null object
# created_at                       2240 non-null datetime64[ns, UTC]
# display_text_start               2240 non-null int64
# display_text_finish              2240 non-null int64
# entities                         2240 non-null object
# extended_entities                2022 non-null object
# favorite_count                   2240 non-null int64
# favorited                        2240 non-null bool
# full_text                        2240 non-null object
# is_quote_status                  2240 non-null bool
# lang                             2240 non-null object
# possibly_sensitive               2160 non-null object
# possibly_sensitive_appealable    2160 non-null object
# quoted_status                    24 non-null object
# quoted_status_id                 26 non-null float64
# ...

# %%
tweets_merged
# Out:
#                 tweet_id                created_at  display_text_start  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00                   0
# 1     892177421306343426 2017-08-01 00:17:27+00:00                   0
# 2     891815181378084864 2017-07-31 00:18:03+00:00                   0
# 3     891689557279858688 2017-07-30 15:58:51+00:00                   0
# 4     891327558926688256 2017-07-29 16:00:24+00:00                   0
# 5     891087950875897856 2017-07-29 00:08:17+00:00                   0
# 6     890971913173991426 2017-07-28 16:27:12+00:00                   0
# 7     890729181411237888 2017-07-28 00:22:40+00:00                   0
# 8     890609185150312448 2017-07-27 16:25:51+00:00                   0
# 9     890240255349198849 2017-07-26 15:59:51+00:00                   0
# 10    890006608113172480 2017-07-26 00:31:25+00:00                   0
# 11    889880896479866881 2017-07-25 16:11:53+00:00                   0
# ...

# %%
df_twts_img = pd.merge(tweets_merged, df_images_clean, on='tweet_id')

# %%
df_twts_img.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2022 entries, 0 to 2021
# Data columns (total 43 columns):
# tweet_id                         2022 non-null object
# created_at                       2022 non-null datetime64[ns, UTC]
# display_text_start               2022 non-null int64
# display_text_finish              2022 non-null int64
# entities                         2022 non-null object
# extended_entities                2022 non-null object
# favorite_count                   2022 non-null int64
# favorited                        2022 non-null bool
# full_text                        2022 non-null object
# is_quote_status                  2022 non-null bool
# lang                             2022 non-null object
# possibly_sensitive               2022 non-null object
# possibly_sensitive_appealable    2022 non-null object
# quoted_status                    0 non-null object
# quoted_status_id                 0 non-null float64
# ...

# %%
df_twts_img
# Out:
#                 tweet_id                created_at  display_text_start  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00                   0
# 1     892177421306343426 2017-08-01 00:17:27+00:00                   0
# 2     891815181378084864 2017-07-31 00:18:03+00:00                   0
# 3     891689557279858688 2017-07-30 15:58:51+00:00                   0
# 4     891327558926688256 2017-07-29 16:00:24+00:00                   0
# 5     891087950875897856 2017-07-29 00:08:17+00:00                   0
# 6     890971913173991426 2017-07-28 16:27:12+00:00                   0
# 7     890729181411237888 2017-07-28 00:22:40+00:00                   0
# 8     890609185150312448 2017-07-27 16:25:51+00:00                   0
# 9     890240255349198849 2017-07-26 15:59:51+00:00                   0
# 10    890006608113172480 2017-07-26 00:31:25+00:00                   0
# 11    889880896479866881 2017-07-25 16:11:53+00:00                   0
# ...

# %% [markdown]
# # End of Cleaning

# %% [markdown]
# # New Issue:
# the final mergerd dataframe has 2240 rows but the all_tweets and df-enhanced both have more rows

# %%
# df_all_tweets_clean.retweeted_status[df_all_tweets_clean.retweeted_status.notnull()]

# %%
df_enhanced_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2333 entries, 0 to 2355
# Data columns (total 10 columns):
# tweet_id                      2333 non-null object
# timestamp                     2333 non-null datetime64[ns, UTC]
# retweeted_status_id           180 non-null float64
# retweeted_status_user_id      180 non-null float64
# retweeted_status_timestamp    180 non-null object
# expanded_urls                 2278 non-null object
# rating_numerator              2333 non-null int64
# rating_denominator            2333 non-null int64
# name                          1605 non-null object
# dog_stage                     366 non-null object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(2), object(5)
# memory usage: 200.5+ KB

# %%
sum(df_enhanced_clean.tweet_id.duplicated())
# Out:
# 0

# %%
sum(df_all_tweets_clean.tweet_id.duplicated())
# Out:
# 0

# %% [markdown]
# # Analysis

# %%
#df_twts_img.groupby(['p3'])['dog_stage'].value_counts()

# %%
tweets_merged.head(1)
# Out:
#              tweet_id                created_at  display_text_start  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00                   0
#
#    display_text_finish                                           entities  \
# 0                   85  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           37405
#
#    favorited                                          full_text  \
# 0      False  This is Phineas. He's a mystical boy. Only eve...
#
#    is_quote_status  ...                                               user  \
# 0            False  ...  {'id': 4196983835, 'id_str': '4196983835', 'na...
#
#                   timestamp retweeted_status_id retweeted_status_user_id  \
# 0 2017-08-01 16:23:56+00:00                 NaN                      NaN
#
#    retweeted_status_timestamp  \
# 0                         NaN
#
# ...

# %%
tweets_merged.describe()
# Out:
#        display_text_start  display_text_finish  favorite_count  \
# count         2240.000000          2240.000000     2240.000000
# mean             0.012500           111.905357     7982.556250
# std              0.591608            26.457681    12257.013636
# min              0.000000            13.000000        0.000000
# 25%              0.000000            94.000000     1409.750000
# 50%              0.000000           116.000000     3496.000000
# 75%              0.000000           137.000000     9894.250000
# max             28.000000           165.000000   161579.000000
#
#        quoted_status_id  retweet_count  retweeted_status_id  \
# count      2.600000e+01    2240.000000         1.650000e+02
# mean       8.113972e+17    2929.147321         7.689095e+17
# std        6.295843e+16    4882.095774         6.134643e+16
# min        6.721083e+17      11.000000         6.661041e+17
# 25%        7.761338e+17     609.250000         7.119983e+17
# ...

# %%
# try to plot all together (only numerical values) to see their relationships
#sns.pairplot(tweets_merged)

# %%
# Lower ratings are typically associated with longer tweet text
tweets_merged.plot(x='display_text_finish', y='rating_numerator', kind='scatter', ylim=(1, 15));

# %%
# There is a positive and strong relationship between the retweet_count and the favorite_count
tweets_merged.plot(x='retweet_count', y='favorite_count', logy=False,kind='scatter');

# %%
# let's fpcus on all the tweets which were received at least 1 like( liked tweets)
# There is a positive and strong relationship between the retweet_count and the favorite_count


tweets_merged[tweets_merged.favorite_count!=0].plot(x='retweet_count', y='favorite_count', 
                                                    logy=False,kind='scatter');

# %%
#Lets plot the linear regression line, quantify the pearsonian 
# coefficient and data modality(maximum frequency):
sns.jointplot('retweet_count','favorite_count',data=tweets_merged[
    tweets_merged.favorite_count!=0],color='b').plot(
    sns.regplot, sns.distplot).annotate(stats.pearsonr);
# Out:
# /Users/Meisam/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# Lets further focus on the frequency plot of the favorite_count.
# Frequency plot shows a positivly skewed distribution
# it is further confirmed by comparing Mean and Median: Mean > Median
median_fav_count = int(tweets_merged[tweets_merged.favorite_count!=0]['favorite_count'].median())
mean_fav_count = int(tweets_merged[tweets_merged.favorite_count!=0]['favorite_count'].mean())


sns.distplot(tweets_merged[tweets_merged.favorite_count!=0]
             ['favorite_count'],bins=30,kde=True).annotate('''Median = {}
Mean = {}'''.format(median_fav_count, mean_fav_count), (125000,0.0001))
plt.axvline(x=median_fav_count, color='red')
plt.axvline(x=mean_fav_count, color='black');

# %%
# Lets further focus on the frequency plot of the retweet_count.
# Frequency plot shows a positivly skewed distribution
# it is further confirmed by comparing Mean and Median: Mean > Median
median_retweet_count = int(tweets_merged[tweets_merged.favorite_count!=0]['retweet_count'].median())
mean_retweet_count = int(tweets_merged[tweets_merged.favorite_count!=0]['retweet_count'].mean())
sns.distplot(tweets_merged[tweets_merged.favorite_count!=0]
             ['retweet_count'],bins=30,kde=True).annotate('''Median = {}
Mean = {}'''.format(median_retweet_count, mean_retweet_count),(60000,0.0003))
plt.axvline(x=median_retweet_count, color='red');
plt.axvline(x=mean_retweet_count, color='black');

# %% [markdown]
# #### Findings:
#
# - Considering that we have removed those tweets with zero 'like' from the plot, we can still see that majority of tweets have been liked less than 4,000 times(Median of data is 3,934). These may be the fans of the page who follow every post and like it.
# - We can also see that there are tweet with more than 4,000 likes. These were possibly those which went viral and got a lot of attention
# - Similar analysis for retweet_count all the liked suggests messages have been generally retweeted less than 2,000 times. The median of the number of retweets is 1,284. You could say these are active fans who retweet the tweeter feed.
#
# - the strong positive relationship is even more pronounced here and we have the pearsonian coefficient of 0.93 for it.

# %%
# Lets look at the linear relationship of retweet_count and favourit count
# among each one the dog_stages
sns.lmplot(x='retweet_count',y='favorite_count',data=tweets_merged
           [tweets_merged.favorite_count!=0],hue='dog_stage',
           palette='bright', aspect = 2,truncate=True);

# %% [markdown]
# comparing these 4 lines, it seems the slope of the regression lines for pupper and puppo is larger than doggo and floofer. this suggest that the number of favourits for the former 2 dog stages grow faster with the number of retweets compared to the later 2 dog stages.

# %%
sns.countplot('rating_numerator',data=tweets_merged,palette='bright',hue='dog_stage');
sns.despine(left=True)

# %% [markdown]
# Clearly, there are more pupper dogs and they cover a larger range of ratings compared to any other doges. doggo comes second and puppo is the third.

# %%
# There are some outlier which can be removed (between 7-15 maybe?).
sns.boxplot(x="rating_numerator", y="dog_stage", data=tweets_merged,palette='muted');

# %% [markdown]
# This graph is really interesting, suggesting that on average pupper dogs  have received a lower rating.

# %%
stopwords = set(STOPWORDS)
# the following function uses a single colomn from a dataframe and plots the wordcloud
#In the following function, random_state is set for reproducibility and collocation=False means 
#that if the same word is encountered in collocation with different words,
#it is still considered as one word (to remove duplicates)
def wordcloud(tweets,col):
    wordcloud = WordCloud(width=800, height=400,collocations=False,background_color="black",stopwords=stopwords,random_state = 2018,max_words=50).generate(" ".join([i for i in tweets[col]]))
    plt.figure( figsize=(20,10))
    plt.imshow(wordcloud)
    plt.axis("off")

# %%
wordcloud(tweets_merged,'full_text')

# %%
# above plot has way too many unrelated words. Lets clean these action words and get to the meat
stopwords.add("https"), stopwords.add("co"), stopwords.add("Meet") ,stopwords.add("someone"),stopwords.add("RT")
stopwords.add("amp"), stopwords.add("Say"), stopwords.add("hello"), stopwords.add("ckin"), stopwords.add("af")
stopwords.add("Thank"), stopwords.add("send"), stopwords.add("know"), stopwords.add("still"), stopwords.add("day")
stopwords.add("want"), stopwords.add("someone"), stopwords.add("Please"), stopwords.add("one"),stopwords.add("time")
stopwords.add("now"), stopwords.add("rather"), stopwords.add("tho"), stopwords.add("quite"), stopwords.add("owner")
stopwords.add("need"), stopwords.add("will"), stopwords.add("stop"), stopwords.add("got"), stopwords.add("never")
stopwords.add("ck"), stopwords.add("back"), stopwords.add("take"), stopwords.add("much"), stopwords.add("thing")
stopwords.add("vid"), stopwords.add("likes"), stopwords.add("Always"), stopwords.add("see"), stopwords.add("trying")
stopwords.add("really"), stopwords.add("stuck"), stopwords.add("think"),stopwords.add("ready"), stopwords.add("clearly")
stopwords.add("make"), stopwords.add("well"), stopwords.add("new"),stopwords.add("slip"), stopwords.add("probably")
stopwords.add("wants"), stopwords.add("appear"), stopwords.add("keep"),stopwords.add("even"), stopwords.add("two")
stopwords.add("sending");

# %%
wordcloud(tweets_merged,'full_text')

# %% [markdown]
# Above WordCount plot clearly shows what are the common theme of the tweets: `dog`s and `dog_rate`. Dog stages are here as well with the most commonly named dog stage being the big `pupper` in the middle.
# Rest of the words show the love and enjoyment that a freindly fluffy little puppy will bring about.
